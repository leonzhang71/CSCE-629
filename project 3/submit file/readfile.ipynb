# %%
import pickle

trees = pickle.load(open("Test_Set_Large_AdjLists_of_Trees", "rb"))
print(max(trees[25]))

print(trees[9])
# Out:
# [453]
# ...

# %%
import pickle

k_values = pickle.load(open("Test_Set_Large_of_k_values", "rb"))

print(len(k_values))

print(k_values)
# Out:
# 100
# [6, 10, 7, 4, 3, 6, 3, 5, 9, 5, 7, 7, 9, 5, 10, 4, 10, 9, 6, 9, 6, 5, 10, 6, 3, 7, 10, 6, 8, 8, 5, 10, 8, 9, 9, 9, 6, 3, 7, 8, 5, 3, 5, 4, 8, 3, 5, 4, 7, 9, 3, 9, 4, 10, 8, 8, 8, 8, 5, 7, 5, 5, 6, 9, 4, 8, 8, 3, 7, 8, 3, 7, 6, 7, 9, 7, 6, 4, 9, 6, 8, 5, 6, 7, 10, 5, 8, 10, 5, 9, 5, 4, 6, 3, 3, 6, 6, 3, 5, 7]
