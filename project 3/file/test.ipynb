# %%
import pickle as pkl

with open("Examples_of_labelling", 'rb') as f:
    obj = pkl.load(f)
    print(obj)
# Out:
# [[5, 4, 3, 4, 5, 0, 2, 0, 5, 2, 4, 1], [2, 0, 2, 0, 1, 1, 2, 2, 0, 1, 0, 0], [6, 0, 3, 3, 2, 1, 5, 4, 0, 3, 3, 6], [0, 4, 2, 3, 6, 4, 0, 5, 2, 6, 3, 1], [1, 0, 1, 3, 1, 1, 2, 2, 0, 3, 3, 1], [6, 2, 4, 5, 1, 3, 2, 5, 0, 5, 4], [6, 1, 0, 2, 6, 6, 8, 3, 4, 9, 5, 7], [1, 6, 7, 5, 6, 3, 4, 2, 0, 1, 3, 5], [4, 3, 1, 6, 0, 1, 8, 5, 7, 5, 9, 2], [3, 8, 5, 2, 5, 6, 1, 0, 2, 7, 4, 1]]

# %%
import pickle

trees = pickle.load(open("Large_Examples_of_AdjLists_of_Trees", "rb"))
print(max(trees[9]))

print(trees[9])
# Out:
# [1101]
# ...

# %%
import pickle

k_values = pickle.load(open("Large_Examples_of_k_values", "rb"))

print(len(k_values))

print(k_values)
# Out:
# 100
# [6, 7, 4, 6, 5, 6, 7, 5, 8, 5, 10, 3, 3, 9, 4, 7, 7, 7, 5, 4, 6, 9, 8, 3, 8, 10, 5, 6, 9, 4, 9, 9, 5, 10, 8, 10, 8, 9, 10, 3, 6, 6, 3, 4, 7, 10, 7, 5, 9, 6, 8, 6, 8, 4, 6, 9, 4, 9, 10, 5, 5, 7, 6, 3, 7, 7, 10, 3, 6, 9, 4, 4, 10, 3, 7, 8, 8, 6, 10, 5, 7, 7, 6, 4, 5, 4, 7, 10, 6, 7, 3, 10, 8, 8, 9, 10, 3, 10, 8, 9]
